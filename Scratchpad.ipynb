# %%
import pandas as pd
import csv

# %%
path = '../Downloads/productSecurityExchangeTypeMapping.csv'
df = pd.read_csv(path,delimiter='|')

# %%
df.head()
# Out:
#               productid securityExchange
# 0  16063438578467349077              EQU
# 1   3871264020596532388              EQU
# 2  15473751718583312885              EQU
# 3  15220361146149106549              EQU
# 4  13561718717741181427              EQU

# %%
df.loc[:, ['securityExchange']]
# Out:
#      securityExchange
# 0                 EQU
# 1                 EQU
# 2                 EQU
# 3                 EQU
# 4                 EQU
# 5                 EQU
# 6                 EQU
# 7                 EQU
# 8                 EQU
# 9                 EQU
# 10                EQU
# 11                EQU
# 12                EQU
# 13                EQU
# 14                EQU
# 15                EQU
# 16                EQU
# 17                EQU
# 18                EQU
# 19                EQU
# 20                EQU
# 21                EQU
# 22                EQU
# 23                EQU
# 24                EQU
# 25                EQU
# 26                EQU
# 27                EQU
# 28                EQU
# 29                EQU
# ...               ...
# 5537              EQU
# 5538              DER
# 5539              DER
# 5540              EQU
# 5541              EQU
# 5542              EQU
# 5543              EQU
# 5544              EQU
# 5545              EQU
# ...

# %%
df.loc[:, 'secExchId'] = df.loc[:, 'securityExchange'].map({'EQU':'211', 'DER':'97'})

# %%
df.loc[:, ['productid','secExchId']]
# Out:
#                  productid secExchId
# 0     16063438578467349077       211
# 1      3871264020596532388       211
# 2     15473751718583312885       211
# 3     15220361146149106549       211
# 4     13561718717741181427       211
# 5     17276146493181720528       211
# 6     18050675640290990071       211
# 7      8728604934105447905       211
# 8     10821343002963919068       211
# 9     13641188918752535957       211
# 10    13412686788872065448       211
# 11    14989283557312339323       211
# 12     5104297335803653632       211
# 13     5819809776947978626       211
# 14    13282122225098549738       211
# 15      804783075167527974       211
# 16    12202984947702566456       211
# 17    15571714568803262223       211
# 18    13767675581426210706       211
# 19     6959986762119169196       211
# 20    14881217030399386110       211
# 21    11145720032900840139       211
# 22     1459793702974518211       211
# 23    17433009104274770823       211
# ...

# %%
df.shape
# Out:
# (5567, 3)
